# %%
import os 
#import dlib
import numpy as np
from pathlib import Path
import pandas as pd
import os
from random import shuffle
from tqdm import tqdm_notebook
import itertools
import shutil
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.models import load_model
from tensorflow.keras.mixed_precision import experimental as mixed_precision
import tensorflow as tf
from random import shuffle
from tqdm import tqdm_notebook
import itertools
import cv2
import shutil

# %%
num_images = 300
img_size = 128

def get_input( folder):
    images = np.zeros((num_images,img_size,img_size,3), dtype = np.float32)
    imagespath = [f for f in os.listdir(folder+"/") if 'jpg' in f]
    #print(dataset+label+folder)
    for i in range(num_images):
        img = cv2.resize(plt.imread(folder+"/"+imagespath[i]), (img_size, img_size), interpolation=cv2.INTER_CUBIC)/255
        images[i] = img
    return [images]
# !unzip "All_Modes_tom_cruise_300_bs6-ep50.zip"

# %%
videos=['0-300','301-600','601-900','901-1200','1201-1500','1501-1800']
num_images=300
img_size=128
for video in videos:
  print(video)
  test_folder1="datset/training/fake/"+video
  test_folder2="datset/training/real/"+video
  batch_input1=get_input(test_folder1)
  batchx1=np.array(batch_input1)
 
  batch_input2=get_input(test_folder2)
  batchx2=np.array(batch_input2)
 
  model=load_model("/content/_xceptionimagenet_300_128_attempt1.h5")
  print("Testing------")
  result1=model.predict(batchx2)
  print("Real Prediction : "+str(result1))
 
  result2=model.predict(batchx1)
  print("Fake Prediction :",result2)

# %%
videos=['0-300','301-600','601-900','901-1200','1201-1500','1501-1800']
video_folder="Preprocessed_For_Reconstruction/Tom_Cruise/Reconstruction frames/Tom_Cruise/TOM_CRUISE_2020_Deepfake_VFX_Breakdown_Side_by_Side_1080p_Trim"
path_names=video_folder.split('/')
prediction_folder="Prediction Folder2/CNN+LSTM/"+path_names[-1]+"/predicted_frames"
ssh = Path(prediction_folder)
ssh.mkdir(parents=True)
num_images=300
img_size=128
result_1=[0.122633964,0.016014516,0.0004752278,0.0010624826,0.007240385,0.0071736276]
result_11=[0.87736603,0.98398548,0.999524772,0.998937517,0.99275962,0.992826372]
result_2=[0.9059637,0.93884337,0.99674445,0.96105707,0.9386033,0.95999265]
result_21=[0.0940363,0.06115663,0.00325555,0.03894293,0.0613967,0.04000735]
t=0
frames=os.listdir(video_folder+"/")
frames.sort()
for m in range(0,300):
  image=cv2.imread(video_folder+"/"+frames[m])
  cv2.imwrite(prediction_folder+"/"+frames[m],image)
for video in videos:
  print(video)
 # test_folder1="datset/training/fake/"+video
 # test_folder2="datset/training/real/"+video
 # batch_input1=get_input(test_folder1)
#batchx1=np.array(batch_input1)

 # batch_input2=get_input(test_folder2)
#  batchx2=np.array(batch_input2)

  #model=load_model("/content/tomcruise/tom_cruise_300_xceptionimagenet_attempt1/_xceptionimagenet_300_128_attempt1.h5")
  #print("Testing------")
  #result1=model.predict(batchx2)
  #print("Real Prediction : "+str(result1))

  #result2=model.predict(batchx1)
  #print("Fake Prediction :",result2)
  result1=[[result_1[t]]]
  result11=[[result_11[t]]]
  result2=[[result_2[t]]]
  result21=[[result_21[t]]]
  t+=1

 

  if result1[0][0]>=0.5:
    if video=='0-300': 
      for i in range(300,600):
        if frames[i] ==".ipynb_checkpoints":
            continue
        image=cv2.imread(video_folder+"/"+frames[i])
        if i<=216:
            destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
        elif i<=290:
            destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
        else:
            destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
        #wide,length,_=(destination.shape)
        cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
        cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5,(35,102,11),thickness=2, lineType=cv2.LINE_AA)
        cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='301-600': 
        for i in range(600,900):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(video_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
          #wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='601-900': 
        for i in range(900,1200):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(video_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
          #wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='901-1200': 
        for i in range(1200,1500):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(video_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
          #wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='1201-1500': 
        for i in range(1500,1800):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(video_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
          #wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    else: 
        for i in range(1800,2241):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(video_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,0,255), 5) 
          #wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
  else:
    if video=='0-300': 
        for i in range(300,600):
            if frames[i] ==".ipynb_checkpoints":
              continue
            image=cv2.imread(video_folder+"/"+frames[i])
            if i<=216:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
            elif i<=290:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
            else:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
            #wide,length,_=(destination.shape)
            cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
            cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
            cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='301-600': 
          for i in range(600,900):
              if frames[i] ==".ipynb_checkpoints":
                continue
              image=cv2.imread(video_folder+"/"+frames[i])
              if i<=216:
                  destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
              elif i<=290:
                  destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
              else:
                  destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
              #wide,length,_=(destination.shape)
              cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
              cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
              cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='601-900': 
          for i in range(900,1200):
            if frames[i] ==".ipynb_checkpoints":
              continue
            image=cv2.imread(video_folder+"/"+frames[i])
            if i<=216:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
            elif i<=290:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
            else:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
            #wide,length,_=(destination.shape)
            cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
            cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
            cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='901-1200': 
          for i in range(1200,1500):
            if frames[i] ==".ipynb_checkpoints":
                continue
            image=cv2.imread(video_folder+"/"+frames[i])
            if i<=216:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
            elif i<=290:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
            else:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
            #wide,length,_=(destination.shape)
            cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
            cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
            cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    elif video=='1201-1500': 
          for i in range(1500,1800):
            if frames[i] ==".ipynb_checkpoints":
              continue
            image=cv2.imread(video_folder+"/"+frames[i])
            if i<=216:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
            elif i<=290:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
            else:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
            #wide,length,_=(destination.shape)
            cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
            cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
            cv2.imwrite(prediction_folder+"/"+frames[i],destination)
    else: 
          for i in range(1800,2241):
            if frames[i] ==".ipynb_checkpoints":
                continue
            image=cv2.imread(video_folder+"/"+frames[i])
            if i<=216:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20,image.shape[0]-100),(0,255,0), 5) 
            elif i<=290:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20-50,image.shape[0]-100),(0,255,0), 5) 
            else:
                destination=cv2.rectangle(image, (3,100), ((image.shape[1]//2)-20+30,image.shape[0]-100),(0,255,0), 5) 
            #wide,length,_=(destination.shape)
            cv2.putText(destination, 'Real:'+str(round(result11[0][0],4)), (30,image.shape[0]-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
            cv2.putText(destination, 'Fake:'+str(round(result1[0][0],4)), (30,image.shape[0]-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
            cv2.imwrite(prediction_folder+"/"+frames[i],destination)

   
  if result2[0][0]>=0.5:
     if video=='0-300': 
      for i in range(300,600):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)  
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='301-600': 
        for i in range(600,900):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='601-900': 
        for i in range(900,1200):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='901-1200': 
        for i in range(1200,1500):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='1201-1500': 
        for i in range(1500,1800):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     else: 
        for i in range(1800,2241):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,  ((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          else:
              destination=cv2.rectangle(image, ((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,0,255), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Fake:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Real:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)      
  else:
     if video=='0-300': 
      for i in range(300,600):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)

     elif video=='301-600': 
        for i in range(600,900):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='601-900': 
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='901-1200': 
        for i in range(1200,1500):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     elif video=='1201-1500': 
        for i in range(1500,1800):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)
     else: 
        for i in range(1800,2241):
          if frames[i] ==".ipynb_checkpoints":
              continue
          image=cv2.imread(prediction_folder+"/"+frames[i])
          if i<=216:
              destination=cv2.rectangle(image,((image.shape[1]//2)-15,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          elif i<=290:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20-45,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          else:
              destination=cv2.rectangle(image,((image.shape[1]//2)-20+35,100),((image.shape[1])-3,image.shape[0]-100),(0,255,0), 5) 
          wide,length,_=(destination.shape)
          cv2.putText(destination, 'Real:'+str(round(result2[0][0],4)), ((image.shape[1])-330,wide-100-35-50), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (35,102,11),thickness=2, lineType=cv2.LINE_AA)
          cv2.putText(destination, 'Fake:'+str(round(result21[0][0],4)), ((image.shape[1])-330,wide-100-35), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (0,0,255),thickness=2, lineType=cv2.LINE_AA)
          cv2.imwrite(prediction_folder+"/"+frames[i],destination)    
print("Frame Prediction Done!!!")
        
images=[]
files=os.listdir(prediction_folder)
files.sort()


for filename in files:
    try:    
        img = cv2.imread(prediction_folder+"/"+filename)
        height, width, layers = img.shape
        height, width, layers = img.shape
        size = (width,height)
        images.append(img)
    except:
        continue
        
print("NOW RECONSTRUCTING---")
    
out = cv2.VideoWriter("TOM_CRUISE_Videos_"+path_names[-1]+'_Reconstructed_CNN+LSTM_Final.mp4',cv2.VideoWriter_fourcc(*'mp4v'), 30, size)

for i in range(len(images)):
    out.write(images[i])

out.release()

print("VIDEO COMPLETED!!!")
